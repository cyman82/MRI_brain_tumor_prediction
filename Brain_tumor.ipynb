# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/MyDrive/Brain Tumor"
# Out:
# data  dataset  models  outputs	training  utils

# %%
# !rsync -ah --progress "/content/drive/MyDrive/Brain Tumor/" "/content/BrainTumor/"
# Out:
# sending incremental file list
# created directory /content/BrainTumor
# ./
# data/
# data/FLAIR_BRATS2020_split/
# data/FLAIR_BRATS2020_split/train/
# data/FLAIR_BRATS2020_split/train/images/
# data/FLAIR_BRATS2020_split/train/images/image_0.npy
#          16.78M 100%   44.98MB/s    0:00:00 (xfr#1, ir-chk=1258/1272)
# data/FLAIR_BRATS2020_split/train/images/image_1.npy
#          16.78M 100%   16.63MB/s    0:00:00 (xfr#2, ir-chk=1257/1272)
# data/FLAIR_BRATS2020_split/train/images/image_10.npy
#          16.78M 100%  293.57kB/s    0:00:55 (xfr#3, ir-chk=1256/1272)
# data/FLAIR_BRATS2020_split/train/images/image_101.npy
#          16.78M 100%  142.86MB/s    0:00:00 (xfr#4, ir-chk=1255/1272)
# data/FLAIR_BRATS2020_split/train/images/image_102.npy
#          16.78M 100%   82.90MB/s    0:00:00 (xfr#5, ir-chk=1254/1272)
# data/FLAIR_BRATS2020_split/train/images/image_103.npy
#          16.78M 100%   14.90MB/s    0:00:01 (xfr#6, ir-chk=1253/1272)
# ...

# %%
import torch

print(torch.cuda.is_available())

print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
os.listdir('/content/drive/MyDrive/Brain Tumor/BrainTumor_Checkpoints')
# Out:
# []

# %%
import os

checkpoint_dir = "/content/drive/MyDrive/BrainTumor_Checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

# %%
# !mkdir -p "/content/drive/MyDrive/BrainTumorOutputs/checkpoints"

# !mkdir -p "/content/drive/MyDrive/BrainTumorOutputs/history"

# !mkdir -p "/content/drive/MyDrive/BrainTumorOutputs/predictions"

# %%
# %cd "/content/BrainTumor"
# Out:
# /content/BrainTumor

# %%
# !ls
# Out:
# data  dataset  models  outputs	training  utils

# %%
# !ls training
# Out:
# __init__.py  losses.py	metrics.py  __pycache__  train.py

# %%
# !python -m training.train
# Out:
# tokenizer_config.json: 100% 592/592 [00:00<00:00, 3.64MB/s]
# vocab.json: 862kB [00:00, 48.6MB/s]
# ...
# merges.txt: 525kB [00:00, 116MB/s]
# tokenizer.json: 2.22MB [00:00, 154MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 2.48MB/s]
# config.json: 4.19kB [00:00, 14.3MB/s]
# pytorch_model.bin: 100% 605M/605M [00:07<00:00, 78.3MB/s]
# model.safetensors:   0% 0.00/605M [00:00<?, ?B/s]
# Loading weights:   0% 0/196 [00:00<?, ?it/s]
# Loading weights:   1% 1/196 [00:00<00:00, 9404.27it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 1/196 [00:00<00:00, 4771.68it/s, Materializing param=text_model.embeddings.position_embedding.weight]
# Loading weights:   1% 2/196 [00:00<00:00, 4438.42it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# Loading weights:   1% 2/196 [00:00<00:00, 3671.16it/s, Materializing param=text_model.embeddings.token_embedding.weight]
# ...

# %%
# !find /content/drive -name "best_model.pth"

# %%
# !find /content/drive -name "training_history.json"
